# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
trans = pd.read_csv('TransQE.csv' , encoding='latin')

# %%
trans.head()
# Out:
#    index                                           original  \
# 0      0  In the flood-prone districts of the Netherland...
# 1      1  Group A Group B The top five run scorers (tota...
# 2      2  The final finished as a draw, with Essex winni...
# 3      3  These traitsestablishment of a working method...
# 4      4  Its two most important members, Britain and Fr...
#
#                                          translation            scores  mean  \
# 0  ???????? ?? ???? ??????? ????? ???, ????? ??? ...  [90, 90, 79, 81]  85.0
# 1  ????? ? ????? ?? ????? ???? ?? ?????? (??? ??)...  [95, 95, 87, 89]  91.5
# 2  ??? ?? ???? ???? ??? ???? ????? ???? ?? ???, ?...  [95, 95, 70, 60]  80.0
# 3  ?? ?????????-??? ?? ?????? ??? ????? ??????? ?...  [90, 90, 78, 78]  84.0
# 4  ???? ?? ???? ?????????? ?????, ??????? ?? ????...  [90, 90, 88, 86]  88.5
#
#                                             z_scores    z_mean  QE_score
# ...

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error

# Calculate Pearson correlation coefficient
pearson_corr = trans['mean'].corr(trans['QE_score'], method='pearson')

# Calculate Spearman correlation coefficient
spearman_corr = trans['mean'].corr(trans['QE_score'], method='spearman')

print(f"Pearson correlation For TransQuest coefficient: {pearson_corr:.4f}")
print(f"Spearman correlation For TransQuest coefficient: {spearman_corr:.4f}")

# Calculate MAE
mae = mean_absolute_error(trans["mean"], trans["QE_score"])
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# Pearson correlation For TransQuest coefficient: 0.3602
# Spearman correlation For TransQuest coefficient: 0.3521
# Mean Absolute Error (MAE): 80.0917

# %%
# 2. COMET

# %%
com = pd.read_csv('dev_with_comet.tsv',sep="\t")

# %%
com.head()
# Out:
#    index                                           original  \
# 0      0  In the flood-prone districts of the Netherland...
# 1      1  Group A Group B The top five run scorers (tota...
# 2      2  The final finished as a draw, with Essex winni...
# 3      3  These traits—establishment of a working method...
# 4      4  Its two most important members, Britain and Fr...
#
#                                          translation            scores  mean  \
# 0  नीदरलैंड के बाढ़ संभावित जिलों में, विशेष रूप ...  [90, 90, 79, 81]  85.0
# 1  ग्रुप ए ग्रुप बी शीर्ष पांच रन स्कोरर (कुल रन)...  [95, 95, 87, 89]  91.5
# 2  मैच की पहली पारी में बढ़त हासिल करने के बाद, ए...  [95, 95, 70, 60]  80.0
# 3  ये विशेषताएं-कला का अभिन्न अंग कार्य प्रणाली क...  [90, 90, 78, 78]  84.0
# 4  इसके दो सबसे महत्वपूर्ण सदस्य, ब्रिटेन और फ्रा...  [90, 90, 88, 86]  88.5
#
#                                             z_scores    z_mean  comet_score  \
# ...

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error

# Calculate Pearson correlation coefficient
pearson_corr = com['mean'].corr(com['comet_score'], method='pearson')

# Calculate Spearman correlation coefficient
spearman_corr = com['mean'].corr(com['comet_score'], method='spearman')

print(f"Pearson correlation For COMET Score coefficient: {pearson_corr:.4f}")
print(f"Spearman correlation For COMET Score  coefficient: {spearman_corr:.4f}")

# Calculate MAE
mae = mean_absolute_error(com["mean"], com["comet_score"])
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# Pearson correlation For COMET Score coefficient: 0.3015
# Spearman correlation For COMET Score  coefficient: 0.3188
# Mean Absolute Error (MAE): 80.6831

# %%
# COMET QE MQM

# %%
comqe = pd.read_csv('comet_qe_mqm_score.csv',encoding='latin')

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error

# Calculate Pearson correlation coefficient
pearson_corr = comqe['mean'].corr(comqe['comet_qe_score'], method='pearson')

# Calculate Spearman correlation coefficient
spearman_corr = comqe['mean'].corr(comqe['comet_qe_score'], method='spearman')

print(f"Pearson correlation For WMT QE MQM coefficient: {pearson_corr:.4f}")
print(f"Spearman correlation For WMT QE MQM coefficient: {spearman_corr:.4f}")

# Calculate MAE
mae = mean_absolute_error(comqe["mean"], comqe["comet_qe_score"])
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# Pearson correlation For WMT QE MQM coefficient: 0.2760
# Spearman correlation For WMT QE MQM coefficient: 0.3258
# Mean Absolute Error (MAE): 80.6590

# %%
# COMET WMT20

# %%
wmt20 = pd.read_csv('wmt20_comet_qe_da_score.csv',encoding = 'latin')

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error

# Calculate Pearson correlation coefficient
pearson_corr = wmt20['mean'].corr(wmt20['wmt20_comet_qe_da_score'], method='pearson')

# Calculate Spearman correlation coefficient
spearman_corr = wmt20['mean'].corr(wmt20['wmt20_comet_qe_da_score'], method='spearman')

print(f"Pearson correlation For WMT20 COMET DA coefficient: {pearson_corr:.4f}")
print(f"Spearman correlation For WMT20 COMET DA coefficient: {spearman_corr:.4f}")

# Calculate MAE
mae = mean_absolute_error(wmt20["mean"], wmt20["wmt20_comet_qe_da_score"])
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# Pearson correlation For WMT20 COMET DA coefficient: 0.2886
# Spearman correlation For WMT20 COMET DA coefficient: 0.3082
# Mean Absolute Error (MAE): 80.4130

# %%
# BLEURT

# %%
bleurt = pd.read_csv('Bleurt_scored_output.tsv',sep="\t")

# %%
bleurt.head()
# Out:
#    index                                           original  \
# 0      0  In the flood-prone districts of the Netherland...
# 1      1  Group A Group B The top five run scorers (tota...
# 2      2  The final finished as a draw, with Essex winni...
# 3      3  These traits—establishment of a working method...
# 4      4  Its two most important members, Britain and Fr...
#
#                                          translation            scores  mean  \
# 0  नीदरलैंड के बाढ़ संभावित जिलों में, विशेष रूप ...  [90, 90, 79, 81]  85.0
# 1  ग्रुप ए ग्रुप बी शीर्ष पांच रन स्कोरर (कुल रन)...  [95, 95, 87, 89]  91.5
# 2  मैच की पहली पारी में बढ़त हासिल करने के बाद, ए...  [95, 95, 70, 60]  80.0
# 3  ये विशेषताएं-कला का अभिन्न अंग कार्य प्रणाली क...  [90, 90, 78, 78]  84.0
# 4  इसके दो सबसे महत्वपूर्ण सदस्य, ब्रिटेन और फ्रा...  [90, 90, 88, 86]  88.5
#
#                                             z_scores    z_mean  bleurt_score
# ...

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error

# Calculate Pearson correlation coefficient
pearson_corr = bleurt['mean'].corr(bleurt['bleurt_score'], method='pearson')

# Calculate Spearman correlation coefficient
spearman_corr = bleurt['mean'].corr(bleurt['bleurt_score'], method='spearman')

print(f"Pearson correlation For BLEURT Score coefficient: {pearson_corr:.4f}")
print(f"Spearman correlation For BLEURT Score coefficient: {spearman_corr:.4f}")

# Calculate MAE
mae = mean_absolute_error(bleurt["mean"], bleurt["bleurt_score"])
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# Pearson correlation For BLEURT Score coefficient: -0.0727
# Spearman correlation For BLEURT Score coefficient: -0.0725
# Mean Absolute Error (MAE): 81.6740

# %%
# BLEU

# %%
bleu = pd.read_csv('scored_with_bleu.tsv',sep="\t")

# %%
bleu.head()
# Out:
#    index                                           original  \
# 0      0  In the flood-prone districts of the Netherland...
# 1      1  Group A Group B The top five run scorers (tota...
# 2      2  The final finished as a draw, with Essex winni...
# 3      3  These traits—establishment of a working method...
# 4      4  Its two most important members, Britain and Fr...
#
#                                          translation            scores  mean  \
# 0  नीदरलैंड के बाढ़ संभावित जिलों में, विशेष रूप ...  [90, 90, 79, 81]  85.0
# 1  ग्रुप ए ग्रुप बी शीर्ष पांच रन स्कोरर (कुल रन)...  [95, 95, 87, 89]  91.5
# 2  मैच की पहली पारी में बढ़त हासिल करने के बाद, ए...  [95, 95, 70, 60]  80.0
# 3  ये विशेषताएं-कला का अभिन्न अंग कार्य प्रणाली क...  [90, 90, 78, 78]  84.0
# 4  इसके दो सबसे महत्वपूर्ण सदस्य, ब्रिटेन और फ्रा...  [90, 90, 88, 86]  88.5
#
#                                             z_scores    z_mean  bleu_score
# ...

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error

# Calculate Pearson correlation coefficient
pearson_corr = bleu['mean'].corr(bleu['bleu_score'], method='pearson')

# Calculate Spearman correlation coefficient
spearman_corr = bleu['mean'].corr(bleu['bleu_score'], method='spearman')

print(f"Pearson correlation For BLEU Score coefficient: {pearson_corr:.4f}")
print(f"Spearman correlation For BLEU Score coefficient: {spearman_corr:.4f}")

# Calculate MAE
mae = mean_absolute_error(bleu["mean"], bleu["bleu_score"])
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# Pearson correlation For BLEU Score coefficient: -0.1426
# Spearman correlation For BLEU Score coefficient: -0.1842
# Mean Absolute Error (MAE): 79.0068

# %%
# Tiny LLama

# %%
tiny = pd.read_csv('dev_scored.tsv',sep="\t")

# %%
tiny.head()
# Out:
#    index                                           original  \
# 0      0  In the flood-prone districts of the Netherland...
# 1      1  Group A Group B The top five run scorers (tota...
# 2      2  The final finished as a draw, with Essex winni...
# 3      3  These traits—establishment of a working method...
# 4      4  Its two most important members, Britain and Fr...
#
#                                          translation            scores  mean  \
# 0  नीदरलैंड के बाढ़ संभावित जिलों में, विशेष रूप ...  [90, 90, 79, 81]  85.0
# 1  ग्रुप ए ग्रुप बी शीर्ष पांच रन स्कोरर (कुल रन)...  [95, 95, 87, 89]  91.5
# 2  मैच की पहली पारी में बढ़त हासिल करने के बाद, ए...  [95, 95, 70, 60]  80.0
# 3  ये विशेषताएं-कला का अभिन्न अंग कार्य प्रणाली क...  [90, 90, 78, 78]  84.0
# 4  इसके दो सबसे महत्वपूर्ण सदस्य, ब्रिटेन और फ्रा...  [90, 90, 88, 86]  88.5
#
#                                             z_scores    z_mean  llama_score
# ...

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error

# Calculate Pearson correlation coefficient
pearson_corr = tiny['mean'].corr(tiny['llama_score'], method='pearson')

# Calculate Spearman correlation coefficient
spearman_corr = tiny['mean'].corr(tiny['llama_score'], method='spearman')

print(f"Pearson correlation For Tiny LLama coefficient: {pearson_corr:.4f}")
print(f"Spearman correlation For Tiny LLama coefficient: {spearman_corr:.4f}")

# Calculate MAE
mae = mean_absolute_error(tiny["mean"], tiny["llama_score"])
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# Pearson correlation For Tiny LLama coefficient: 0.0515
# Spearman correlation For Tiny LLama coefficient: -0.0063
# Mean Absolute Error (MAE): 22.8448
